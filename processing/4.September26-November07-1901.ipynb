# %% [markdown]
# This notebook processes OCR content contained in .json files, generated in Microsoft AI Studio and manually added to the 'source' directory.

# %%
# Import modules and set variables and directories.
import os, sys, re, json, re, logging

# Manually set the root directory path
root_dir = '../'
sys.path.append(root_dir)

from modules.exclusions import excluded_strings, excluded_patterns

# Define the primary source file you're working with
hansard_source_file_name = '4.September26-November07-1901'  
# Define the hathi_starting_page. This is the unique Hathi identifier for the Google pdf, and the page in that pdf that corresponds to the first page of Hansard in the original digitized source. It is used to concatenate the url to the Hathi Trust source in the last cell of the notebook.
hathi_id = 'uc1.32106019788261'
hathi_starting_page = 41  

# Concatenate hansard_source_file to source_dir and output_dir_path
source_dir_path = os.path.join('../source', hansard_source_file_name)
output_pages_dir_path = os.path.join('../output', 'pages', hansard_source_file_name)
output_sessions_dir_path = os.path.join('../output', 'sessions', hansard_source_file_name)

# Check if source directory exists
if not os.path.exists(source_dir_path):
    os.makedirs(source_dir_path)

# Check if output directory exists
if not os.path.exists(output_pages_dir_path):
    os.makedirs(output_pages_dir_path)

# Create logs directory if it doesn't exist
logs_dir_path = os.path.join('../logs')
if not os.path.exists(logs_dir_path):
    os.makedirs(logs_dir_path)

# Set up basic logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Get the root logger
logger = logging.getLogger()

# If the logger has handlers, remove them
if logger.hasHandlers():
    logger.handlers.clear()

# Create a new file handler that overwrites the log file each time
log_file_path = os.path.join(logs_dir_path, '4.September26-November07-1901_exclusions.log')
file_handler = logging.FileHandler(log_file_path, mode='w')
file_handler.setLevel(logging.INFO)

# Create a logging format
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
file_handler.setFormatter(formatter)

# Add the handler to the logger
logger.addHandler(file_handler)

# Log the excluded strings and patterns
logger.info(f"Excluded strings: {excluded_strings}, Excluded patterns: {excluded_patterns}")

# %%
# Use the OCR content (manually produced in and downloaded from Microsoft AI Studio) and associated positional data to generate page files from the two column layout, removing digitization metadata.

# Get all files in the source directory
files_in_directory = os.listdir(source_dir_path)

# Filter for json files
json_files = [file for file in files_in_directory if file.endswith('.json')]

# Now you can iterate over the json_files list and process each file
for json_file in json_files:
    input_source_file = os.path.join(source_dir_path, json_file)

    # Load the JSON file
    with open(input_source_file) as f:
        data = json.load(f)

    # Access the "analyzeResult"
    analyze_result = data['analyzeResult']

    # Iterate over each page
    for page in analyze_result['pages']:
        # Create a variable to store the page content
        page_content = ""

        # Calculate the x-coordinate that separates the two columns
        column_separator = page['width'] / 2

        # Divide the text lines into two groups based on their x-coordinate
        left_column_lines = [line for line in page['lines'] if min(line['polygon'][::2]) < column_separator]
        right_column_lines = [line for line in page['lines'] if min(line['polygon'][::2]) >= column_separator]

        # Sort each group of text lines by their y-coordinate (top to bottom)
        left_column_lines.sort(key=lambda line: min(line['polygon'][1::2]))
        right_column_lines.sort(key=lambda line: min(line['polygon'][1::2]))

        # Combine the sorted text lines from the two columns
        sorted_lines = left_column_lines + right_column_lines


        # Define the areas of the page you want to exclude
        x_range = (0, 0.1 * page['width'])  # Capture the left ~10% of the page. Callibrate to suit.
        y_range = (0.95 * page['height'], page['height'])  # Capture the bottom ~10% of the page. Callibrate to suit.
        header_y_range = (0, 0.1 * page['height'])  # Capture the top ~10% of the page. Callibrate to suit.

        # Iterate over each text line in the page
        for line in sorted_lines:
            # Check if any of the y-coordinates of the line fall within the y_range
            y_coordinates = line['polygon'][1::2]
            if any(y_range[0] <= y <= y_range[1] for y in y_coordinates) or any(header_y_range[0] <= y <= header_y_range[1] for y in y_coordinates):
                # If y-coordinate condition is met, log the line and continue to next iteration
                logging.info(f"Excluded due to y_range or header_y_range: {line}")
                continue

            # If condition is false, add the line to the page content
            content = line['content']
            page_content += content + " "

        # Write the page content to a new file in the output directory
        output_file_path = os.path.join(output_pages_dir_path, f'page_{page["pageNumber"]}.md')
        with open(output_file_path, 'w') as f:
            f.write(page_content)

# %%
# Combine the pages into a single master content file, for cleaning.

combined_file = os.path.join(output_pages_dir_path, 'all_pages_master.txt')

def sort_key(filename):
    match = re.search(r'page_(\d+)', filename)
    if match:
        return int(match.group(1))
    return float('inf')

with open(combined_file, 'w') as outfile:
    for filename in sorted(os.listdir(output_pages_dir_path), key=sort_key):
        if filename.startswith('page_') and filename.endswith('.md'):
            page_number = filename.replace('page_', '').replace('.md', '')
            outfile.write(f'<page:{page_number}>\n')
            with open(os.path.join(output_pages_dir_path, filename), 'r') as infile:
                for line in infile:
                    outfile.write(line.lstrip())  # strip leading whitespace
                outfile.write('\n')

# %%
# Clean the master content file, using local processing

# Read the content
with open(combined_file, 'r') as file:
    lines = file.readlines()

# Remove patterns matching excluded patterns
for pattern in excluded_patterns:
    lines = [re.sub(pattern, '', line) for line in lines]

# Remove strings matching excluded strings
for string in excluded_strings:
    logging.info(f"Removing string: {string}")
    lines = [line.replace(string, '') for line in lines]

# Remove unwanted indentation
lines = [line.lstrip() for line in lines]

# Write the cleaned content back
master_file_path = os.path.join(output_pages_dir_path, 'all_pages_master.txt')
with open(master_file_path, 'w') as file:
    file.writelines(lines)

# %%
# Split the cleaned master file into sessions, adding page tags.

# Open the master file
with open(master_file_path, 'r') as file:
    # Read the content
    content = file.read()

    # Define the pattern for 'LEGISLATIVE COUNCIL.' followed by a date
    pattern = r'(LEGISLATIVE COUNCIL\.\s*(?:Monday|Tuesday|Wednesday|Thursday|Friday|Saturday|Sunday), (?:\d{1,2}|[IVX]{1,3})(?:st|nd|rd|th) \w+, \d{4})'

    # Find all matches of the pattern
    matches = re.findall(pattern, content)

    # Split the content based on the pattern
    parts = re.split(pattern, content)

    # Iterate over the parts, skipping the first
    for i in range(1, len(parts), 2):
        # Extract the date string following 'LEGISLATIVE COUNCIL.'
        date_match = re.search(r'(?:Monday|Tuesday|Wednesday|Thursday|Friday|Saturday|Sunday), (?:\d{1,2}|[IVX]{1,3})(?:st|nd|rd|th) \w+, \d{4}', parts[i])
        date = date_match.group() if date_match else 'No date'

        # Format the filename
        filename = f'{i//2+1}-{date}.txt'

        # Concatenate output_dir_path with subdirectory and filename
        file_path = os.path.join(output_sessions_dir_path, filename)

        # Ensure the directory exists
        os.makedirs(os.path.dirname(file_path), exist_ok=True)

        # Check if the part starts with a <page> tag
        if not parts[i].strip().startswith('<page>'):
            # Find the first <page> tag in the part
            page_tag_match = re.search(r'<page:(\d+)>', parts[i+1])
            if page_tag_match:
                # Derive the first <page> tag
                first_page_number = int(page_tag_match.group(1)) - 1
                first_page_tag = f'<page>{first_page_number}</page>\n'
                # Prepend the first <page> tag to the part
                parts[i] = first_page_tag + parts[i]

        # Reformat <page:123> to <page>123</page>
        parts[i] = re.sub(r'<page:(\d+)>', r'<page>\1</page>', parts[i])
        parts[i+1] = re.sub(r'<page:(\d+)>', r'<page>\1</page>', parts[i+1])

        # Open the file using the variable
        with open(file_path, 'w', encoding='utf-8') as file:
            # Write the matched pattern and the following part to the file
            file.write(parts[i] + parts[i+1])

# %%
# Needed for this volume, to manage inconsistencies between the page numbers of the (edited) version of the Google pdf used for OCR and the Hathi PDF. This can be considered a bug. The best solution would be to re-transcribe (produce new .json source files) from the original Google Pdfs, although this would require additional post-OCR cleaning.

def get_last_page_numbers(output_sessions_dir_path):
    last_page_numbers = {}

    # Sort filenames based on the numeric part at the beginning
    filenames = sorted(os.listdir(output_sessions_dir_path), key=lambda x: int(re.findall(r'^\d+', x)[0]) if re.findall(r'^\d+', x) else float('inf'))

    for filename in filenames:
        if filename.endswith(".txt"):
            filepath = os.path.join(output_sessions_dir_path, filename)
            with open(filepath, 'r') as file:
                content = file.read()

            # Find all <page> tags
            page_tags = re.findall(r'<page>\d+</page>', content)
            if page_tags:
                # Extract the last page number
                last_page_number = int(re.findall(r'\d+', page_tags[-1])[0])
                last_page_numbers[filename] = last_page_number

    return last_page_numbers

def reset_page_tags(directory, last_page_numbers):
    page_number = 1
    previous_last_page_number = None
    previous_filename = None

    # Sort filenames based on the numeric part at the beginning
    filenames = sorted(os.listdir(directory), key=lambda x: int(re.findall(r'^\d+', x)[0]) if re.findall(r'^\d+', x) else float('inf'))

    for filename in filenames:
        if filename.endswith(".txt"):
            filepath = os.path.join(directory, filename)
            with open(filepath, 'r') as file:
                content = file.read()

            # Find all <page> tags
            page_tags = re.findall(r'<page>\d+</page>', content)

            if page_tags:
                first_page_number = int(re.findall(r'\d+', page_tags[0])[0])

                if previous_last_page_number is not None and first_page_number == previous_last_page_number:
                    # Retrieve the updated last page number from the previous file
                    if previous_filename:
                        previous_filepath = os.path.join(directory, previous_filename)
                        with open(previous_filepath, 'r') as prev_file:
                            prev_content = prev_file.read()
                        prev_page_tags = re.findall(r'<page>\d+</page>', prev_content)
                        if prev_page_tags:
                            new_last_page_number = int(re.findall(r'\d+', prev_page_tags[-1])[0])
                            # Start page numbering using new_last_page_number
                            page_number = new_last_page_number

            # Replace each <page> tag with the new sequence number
            for tag in page_tags:
                new_tag = f'<page>{page_number}</page>'
                content = content.replace(tag, new_tag, 1)
                page_number += 1

            # Write the modified content back to the file
            with open(filepath, 'w') as file:
                file.write(content)

            # Update the previous last page number and filename
            if page_tags:
                previous_last_page_number = int(re.findall(r'\d+', page_tags[-1])[0])
                previous_filename = filename

# First pass to get the last page numbers
last_page_numbers = get_last_page_numbers(output_sessions_dir_path)

# Second pass to reset the page tags
reset_page_tags(output_sessions_dir_path, last_page_numbers)

# %%
# Concatenate urls to the Hathi Trust source documents, and add them below the page numbers.

# Initialize the current Hathi page number
current_hathi_page = hathi_starting_page

def process_file(file_path, hathi_id, hathi_starting_page):
    global current_hathi_page
    
    print(f"Processing file: {file_path}")

    # Read the content of the file
    with open(file_path, 'r') as file:
        content = file.read()    
 
    # Split the content by lines
    lines = content.split('\n')
    new_lines = []
    
    # Iterate over each line and process <page> tags
    for line in lines:
        page_match = re.match(r'<page>(\d+)</page>', line)
        
        if page_match:
            # Keep the original page number
            page_number = int(page_match.group(1))
            new_lines.append(f'<page>{page_number}</page>')
            
            # Calculate the HathiTrust page number based on the delta
            hathi_page_number = hathi_starting_page + (page_number - 1)
            url = f'https://babel.hathitrust.org/cgi/pt?id={hathi_id}&seq={hathi_page_number}'
            new_lines.append(f'<url>{url}</url>')
            print(f"Updated line: <page>{page_number}</page> and <url>{url}</url>")
        else:
            url_match = re.match(r'<url>https://babel.hathitrust.org/cgi/pt\?id=.*&seq=\d+</url>', line)
            if url_match:
                # Skip the existing URL line
                continue
            else:
                new_lines.append(line)
    
    # Join the new lines to form the updated content
    updated_content = '\n'.join(new_lines)
    
    # Write the updated content to the file
    with open(file_path, 'w') as file:
        file.write(updated_content)

    print(f"Finished processing file: {file_path}")

# Iterate over each file in the subdirectory
for filename in sorted(os.listdir(output_sessions_dir_path)):
    if filename.endswith('.txt'):
        file_path = os.path.join(output_sessions_dir_path, filename)
        process_file(file_path, hathi_id, hathi_starting_page)
# Out:
# Processing file: ../output/sessions/4.September26-November07-1901/1-Thursday, 26th September, 1901.txt
# Updated line: <page>1</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=41</url>
# Updated line: <page>2</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=42</url>
# Updated line: <page>3</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=43</url>
# Updated line: <page>4</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=44</url>
# Updated line: <page>5</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=45</url>
# Updated line: <page>6</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=46</url>
# Updated line: <page>7</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=47</url>
# Updated line: <page>8</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=48</url>
# Updated line: <page>9</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=49</url>
# Updated line: <page>10</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=50</url>
# Updated line: <page>11</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=51</url>
# Updated line: <page>12</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=52</url>
# Updated line: <page>13</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=53</url>
# Updated line: <page>14</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=54</url>
# Updated line: <page>15</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=55</url>
# Updated line: <page>16</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=56</url>
# Updated line: <page>17</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=57</url>
# Updated line: <page>18</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=58</url>
# Updated line: <page>19</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=59</url>
# Updated line: <page>20</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=60</url>
# Updated line: <page>21</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=61</url>
# Updated line: <page>22</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=62</url>
# Updated line: <page>23</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=63</url>
# Updated line: <page>24</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=64</url>
# Updated line: <page>25</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=65</url>
# Updated line: <page>26</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=66</url>
# Updated line: <page>27</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=67</url>
# Updated line: <page>28</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=68</url>
# Updated line: <page>29</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=69</url>
# Updated line: <page>30</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=70</url>
# Updated line: <page>31</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=71</url>
# Updated line: <page>32</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=72</url>
# Updated line: <page>33</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=73</url>
# Updated line: <page>34</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=74</url>
# Updated line: <page>35</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=75</url>
# Updated line: <page>36</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=76</url>
# Updated line: <page>37</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=77</url>
# Updated line: <page>38</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=78</url>
# Updated line: <page>39</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=79</url>
# Finished processing file: ../output/sessions/4.September26-November07-1901/1-Thursday, 26th September, 1901.txt
# Processing file: ../output/sessions/4.September26-November07-1901/10-Tuesday, 15th October, 1901.txt
# Updated line: <page>389</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=429</url>
# Updated line: <page>390</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=430</url>
# Updated line: <page>391</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=431</url>
# Updated line: <page>392</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=432</url>
# Updated line: <page>393</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=433</url>
# Updated line: <page>394</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=434</url>
# Updated line: <page>395</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=435</url>
# Updated line: <page>396</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=436</url>
# Updated line: <page>397</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=437</url>
# Updated line: <page>398</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=438</url>
# Updated line: <page>399</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=439</url>
# Updated line: <page>400</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=440</url>
# Updated line: <page>401</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=441</url>
# Updated line: <page>402</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=442</url>
# Updated line: <page>403</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=443</url>
# Updated line: <page>404</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=444</url>
# Updated line: <page>405</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=445</url>
# Updated line: <page>406</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=446</url>
# Updated line: <page>407</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=447</url>
# Updated line: <page>408</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=448</url>
# Updated line: <page>409</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=449</url>
# Updated line: <page>410</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=450</url>
# Updated line: <page>411</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=451</url>
# Updated line: <page>412</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=452</url>
# Updated line: <page>413</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=453</url>
# Updated line: <page>414</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=454</url>
# Updated line: <page>415</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=455</url>
# Updated line: <page>416</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=456</url>
# Updated line: <page>417</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=457</url>
# Updated line: <page>418</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=458</url>
# Updated line: <page>419</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=459</url>
# Updated line: <page>420</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=460</url>
# Updated line: <page>421</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=461</url>
# Updated line: <page>422</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=462</url>
# Updated line: <page>423</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=463</url>
# Updated line: <page>424</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=464</url>
# Updated line: <page>425</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=465</url>
# Updated line: <page>426</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=466</url>
# Updated line: <page>427</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=467</url>
# Updated line: <page>428</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=468</url>
# Updated line: <page>429</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=469</url>
# Updated line: <page>430</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=470</url>
# Updated line: <page>431</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=471</url>
# Updated line: <page>432</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=472</url>
# Updated line: <page>433</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=473</url>
# Updated line: <page>434</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=474</url>
# Updated line: <page>435</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=475</url>
# Updated line: <page>436</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=476</url>
# Updated line: <page>437</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=477</url>
# Updated line: <page>438</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=478</url>
# Updated line: <page>439</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=479</url>
# Updated line: <page>440</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=480</url>
# Updated line: <page>441</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=481</url>
# Updated line: <page>442</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=482</url>
# Finished processing file: ../output/sessions/4.September26-November07-1901/10-Tuesday, 15th October, 1901.txt
# Processing file: ../output/sessions/4.September26-November07-1901/11-Wednesday, 16th October, 1901.txt
# Updated line: <page>442</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=482</url>
# Updated line: <page>443</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=483</url>
# Updated line: <page>444</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=484</url>
# Updated line: <page>445</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=485</url>
# Updated line: <page>446</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=486</url>
# Finished processing file: ../output/sessions/4.September26-November07-1901/11-Wednesday, 16th October, 1901.txt
# Processing file: ../output/sessions/4.September26-November07-1901/12-Thursday, 17th October, 1901.txt
# Updated line: <page>446</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=486</url>
# Updated line: <page>447</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=487</url>
# Updated line: <page>448</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=488</url>
# Updated line: <page>449</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=489</url>
# Updated line: <page>450</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=490</url>
# Updated line: <page>451</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=491</url>
# Updated line: <page>452</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=492</url>
# Updated line: <page>453</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=493</url>
# Updated line: <page>454</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=494</url>
# Updated line: <page>455</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=495</url>
# Updated line: <page>456</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=496</url>
# Updated line: <page>457</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=497</url>
# Updated line: <page>458</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=498</url>
# Updated line: <page>459</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=499</url>
# Updated line: <page>460</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=500</url>
# Updated line: <page>461</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=501</url>
# Updated line: <page>462</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=502</url>
# Updated line: <page>463</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=503</url>
# Updated line: <page>464</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=504</url>
# Updated line: <page>465</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=505</url>
# Updated line: <page>466</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=506</url>
# Updated line: <page>467</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=507</url>
# Updated line: <page>468</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=508</url>
# Updated line: <page>469</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=509</url>
# Updated line: <page>470</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=510</url>
# Updated line: <page>471</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=511</url>
# Updated line: <page>472</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=512</url>
# Updated line: <page>473</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=513</url>
# Updated line: <page>474</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=514</url>
# Updated line: <page>475</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=515</url>
# Updated line: <page>476</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=516</url>
# Updated line: <page>477</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=517</url>
# Updated line: <page>478</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=518</url>
# Updated line: <page>479</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=519</url>
# Updated line: <page>480</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=520</url>
# Updated line: <page>481</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=521</url>
# Updated line: <page>482</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=522</url>
# Updated line: <page>483</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=523</url>
# Updated line: <page>484</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=524</url>
# Updated line: <page>485</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=525</url>
# Updated line: <page>486</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=526</url>
# Updated line: <page>487</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=527</url>
# Updated line: <page>488</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=528</url>
# Updated line: <page>489</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=529</url>
# Updated line: <page>490</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=530</url>
# Updated line: <page>491</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=531</url>
# Updated line: <page>492</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=532</url>
# Updated line: <page>493</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=533</url>
# Updated line: <page>494</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=534</url>
# Updated line: <page>495</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=535</url>
# Updated line: <page>496</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=536</url>
# Updated line: <page>497</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=537</url>
# Updated line: <page>498</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=538</url>
# Updated line: <page>499</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=539</url>
# Updated line: <page>500</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=540</url>
# Updated line: <page>501</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=541</url>
# Updated line: <page>502</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=542</url>
# Updated line: <page>503</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=543</url>
# Updated line: <page>504</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=544</url>
# Updated line: <page>505</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=545</url>
# Updated line: <page>506</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=546</url>
# Updated line: <page>507</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=547</url>
# Updated line: <page>508</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=548</url>
# Updated line: <page>509</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=549</url>
# Finished processing file: ../output/sessions/4.September26-November07-1901/12-Thursday, 17th October, 1901.txt
# Processing file: ../output/sessions/4.September26-November07-1901/13-Friday, 18th October, 1901.txt
# Updated line: <page>509</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=549</url>
# Updated line: <page>510</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=550</url>
# Updated line: <page>511</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=551</url>
# Updated line: <page>512</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=552</url>
# Updated line: <page>513</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=553</url>
# Updated line: <page>514</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=554</url>
# Updated line: <page>515</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=555</url>
# Updated line: <page>516</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=556</url>
# Updated line: <page>517</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=557</url>
# Updated line: <page>518</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=558</url>
# Updated line: <page>519</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=559</url>
# Updated line: <page>520</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=560</url>
# Updated line: <page>521</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=561</url>
# Updated line: <page>522</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=562</url>
# Updated line: <page>523</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=563</url>
# Updated line: <page>524</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=564</url>
# Updated line: <page>525</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=565</url>
# Updated line: <page>526</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=566</url>
# Updated line: <page>527</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=567</url>
# Updated line: <page>528</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=568</url>
# Updated line: <page>529</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=569</url>
# Updated line: <page>530</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=570</url>
# Updated line: <page>531</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=571</url>
# Updated line: <page>532</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=572</url>
# Updated line: <page>533</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=573</url>
# Updated line: <page>534</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=574</url>
# Updated line: <page>535</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=575</url>
# Updated line: <page>536</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=576</url>
# Updated line: <page>537</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=577</url>
# Updated line: <page>538</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=578</url>
# Updated line: <page>539</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=579</url>
# Updated line: <page>540</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=580</url>
# Updated line: <page>541</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=581</url>
# Updated line: <page>542</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=582</url>
# Updated line: <page>543</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=583</url>
# Updated line: <page>544</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=584</url>
# Updated line: <page>545</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=585</url>
# Updated line: <page>546</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=586</url>
# Updated line: <page>547</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=587</url>
# Updated line: <page>548</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=588</url>
# Updated line: <page>549</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=589</url>
# Updated line: <page>550</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=590</url>
# Updated line: <page>551</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=591</url>
# Updated line: <page>552</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=592</url>
# Updated line: <page>553</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=593</url>
# Updated line: <page>554</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=594</url>
# Updated line: <page>555</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=595</url>
# Updated line: <page>556</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=596</url>
# Updated line: <page>557</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=597</url>
# Updated line: <page>558</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=598</url>
# Updated line: <page>559</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=599</url>
# Updated line: <page>560</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=600</url>
# Updated line: <page>561</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=601</url>
# Updated line: <page>562</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=602</url>
# Updated line: <page>563</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=603</url>
# Updated line: <page>564</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=604</url>
# Updated line: <page>565</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=605</url>
# Updated line: <page>566</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=606</url>
# Updated line: <page>567</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=607</url>
# Updated line: <page>568</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=608</url>
# Updated line: <page>569</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=609</url>
# Updated line: <page>570</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=610</url>
# Updated line: <page>571</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=611</url>
# Updated line: <page>572</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=612</url>
# Updated line: <page>573</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=613</url>
# Updated line: <page>574</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=614</url>
# Updated line: <page>575</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=615</url>
# Updated line: <page>576</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=616</url>
# Updated line: <page>577</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=617</url>
# Updated line: <page>578</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=618</url>
# Updated line: <page>579</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=619</url>
# Finished processing file: ../output/sessions/4.September26-November07-1901/13-Friday, 18th October, 1901.txt
# Processing file: ../output/sessions/4.September26-November07-1901/14-Tuesday, 22nd October, 1901.txt
# Updated line: <page>579</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=619</url>
# Updated line: <page>580</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=620</url>
# Updated line: <page>581</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=621</url>
# Updated line: <page>582</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=622</url>
# Updated line: <page>583</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=623</url>
# Updated line: <page>584</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=624</url>
# Updated line: <page>585</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=625</url>
# Updated line: <page>586</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=626</url>
# Updated line: <page>587</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=627</url>
# Updated line: <page>588</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=628</url>
# Updated line: <page>589</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=629</url>
# Updated line: <page>590</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=630</url>
# Updated line: <page>591</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=631</url>
# Updated line: <page>592</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=632</url>
# Updated line: <page>593</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=633</url>
# Updated line: <page>594</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=634</url>
# Updated line: <page>595</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=635</url>
# Updated line: <page>596</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=636</url>
# Updated line: <page>597</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=637</url>
# Updated line: <page>598</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=638</url>
# Updated line: <page>599</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=639</url>
# Updated line: <page>600</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=640</url>
# Updated line: <page>601</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=641</url>
# Updated line: <page>602</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=642</url>
# Updated line: <page>603</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=643</url>
# Updated line: <page>604</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=644</url>
# Updated line: <page>605</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=645</url>
# Updated line: <page>606</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=646</url>
# Updated line: <page>607</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=647</url>
# Updated line: <page>608</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=648</url>
# Updated line: <page>609</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=649</url>
# Updated line: <page>610</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=650</url>
# Updated line: <page>611</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=651</url>
# Updated line: <page>612</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=652</url>
# Updated line: <page>613</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=653</url>
# Updated line: <page>614</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=654</url>
# Updated line: <page>615</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=655</url>
# Updated line: <page>616</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=656</url>
# Updated line: <page>617</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=657</url>
# Updated line: <page>618</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=658</url>
# Updated line: <page>619</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=659</url>
# Updated line: <page>620</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=660</url>
# Updated line: <page>621</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=661</url>
# Updated line: <page>622</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=662</url>
# Updated line: <page>623</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=663</url>
# Updated line: <page>624</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=664</url>
# Updated line: <page>625</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=665</url>
# Updated line: <page>626</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=666</url>
# Updated line: <page>627</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=667</url>
# Updated line: <page>628</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=668</url>
# Updated line: <page>629</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=669</url>
# Updated line: <page>630</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=670</url>
# Updated line: <page>631</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=671</url>
# Updated line: <page>632</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=672</url>
# Updated line: <page>633</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=673</url>
# Updated line: <page>634</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=674</url>
# Updated line: <page>635</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=675</url>
# Updated line: <page>636</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=676</url>
# Updated line: <page>637</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=677</url>
# Updated line: <page>638</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=678</url>
# Updated line: <page>639</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=679</url>
# Updated line: <page>640</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=680</url>
# Updated line: <page>641</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=681</url>
# Updated line: <page>642</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=682</url>
# Updated line: <page>643</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=683</url>
# Updated line: <page>644</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=684</url>
# Updated line: <page>645</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=685</url>
# Updated line: <page>646</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=686</url>
# Updated line: <page>647</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=687</url>
# Finished processing file: ../output/sessions/4.September26-November07-1901/14-Tuesday, 22nd October, 1901.txt
# Processing file: ../output/sessions/4.September26-November07-1901/15-Wednesday, 23rd October, 1901.txt
# Updated line: <page>647</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=687</url>
# Updated line: <page>648</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=688</url>
# Updated line: <page>649</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=689</url>
# Updated line: <page>650</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=690</url>
# Updated line: <page>651</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=691</url>
# Updated line: <page>652</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=692</url>
# Updated line: <page>653</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=693</url>
# Updated line: <page>654</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=694</url>
# Updated line: <page>655</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=695</url>
# Updated line: <page>656</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=696</url>
# Updated line: <page>657</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=697</url>
# Updated line: <page>658</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=698</url>
# Updated line: <page>659</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=699</url>
# Updated line: <page>660</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=700</url>
# Updated line: <page>661</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=701</url>
# Updated line: <page>662</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=702</url>
# Updated line: <page>663</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=703</url>
# Updated line: <page>664</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=704</url>
# Updated line: <page>665</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=705</url>
# Updated line: <page>666</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=706</url>
# Updated line: <page>667</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=707</url>
# Updated line: <page>668</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=708</url>
# Updated line: <page>669</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=709</url>
# Updated line: <page>670</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=710</url>
# Updated line: <page>671</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=711</url>
# Updated line: <page>672</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=712</url>
# Updated line: <page>673</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=713</url>
# Updated line: <page>674</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=714</url>
# Updated line: <page>675</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=715</url>
# Updated line: <page>676</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=716</url>
# Updated line: <page>677</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=717</url>
# Updated line: <page>678</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=718</url>
# Updated line: <page>679</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=719</url>
# Updated line: <page>680</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=720</url>
# Updated line: <page>681</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=721</url>
# Updated line: <page>682</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=722</url>
# Updated line: <page>683</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=723</url>
# Updated line: <page>684</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=724</url>
# Updated line: <page>685</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=725</url>
# Updated line: <page>686</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=726</url>
# Updated line: <page>687</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=727</url>
# Updated line: <page>688</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=728</url>
# Updated line: <page>689</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=729</url>
# Updated line: <page>690</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=730</url>
# Updated line: <page>691</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=731</url>
# Updated line: <page>692</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=732</url>
# Updated line: <page>693</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=733</url>
# Updated line: <page>694</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=734</url>
# Updated line: <page>695</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=735</url>
# Updated line: <page>696</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=736</url>
# Updated line: <page>697</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=737</url>
# Updated line: <page>698</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=738</url>
# Updated line: <page>699</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=739</url>
# Updated line: <page>700</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=740</url>
# Updated line: <page>701</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=741</url>
# Updated line: <page>702</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=742</url>
# Updated line: <page>703</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=743</url>
# Updated line: <page>704</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=744</url>
# Updated line: <page>705</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=745</url>
# Updated line: <page>706</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=746</url>
# Updated line: <page>707</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=747</url>
# Updated line: <page>708</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=748</url>
# Updated line: <page>709</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=749</url>
# Updated line: <page>710</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=750</url>
# Updated line: <page>711</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=751</url>
# Updated line: <page>712</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=752</url>
# Updated line: <page>713</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=753</url>
# Updated line: <page>714</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=754</url>
# Updated line: <page>715</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=755</url>
# Updated line: <page>716</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=756</url>
# Updated line: <page>717</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=757</url>
# Updated line: <page>718</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=758</url>
# Updated line: <page>719</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=759</url>
# Updated line: <page>720</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=760</url>
# Updated line: <page>721</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=761</url>
# Updated line: <page>722</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=762</url>
# Updated line: <page>723</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=763</url>
# Updated line: <page>724</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=764</url>
# Updated line: <page>725</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=765</url>
# Updated line: <page>726</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=766</url>
# Updated line: <page>727</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=767</url>
# Updated line: <page>728</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=768</url>
# Updated line: <page>729</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=769</url>
# Updated line: <page>730</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=770</url>
# Updated line: <page>731</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=771</url>
# Updated line: <page>732</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=772</url>
# Updated line: <page>733</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=773</url>
# Updated line: <page>734</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=774</url>
# Updated line: <page>735</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=775</url>
# Updated line: <page>736</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=776</url>
# Updated line: <page>737</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=777</url>
# Updated line: <page>738</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=778</url>
# Updated line: <page>739</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=779</url>
# Updated line: <page>740</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=780</url>
# Updated line: <page>741</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=781</url>
# Updated line: <page>742</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=782</url>
# Updated line: <page>743</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=783</url>
# Updated line: <page>744</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=784</url>
# Updated line: <page>745</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=785</url>
# Updated line: <page>746</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=786</url>
# Updated line: <page>747</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=787</url>
# Updated line: <page>748</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=788</url>
# Updated line: <page>749</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=789</url>
# Updated line: <page>750</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=790</url>
# Updated line: <page>751</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=791</url>
# Updated line: <page>752</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=792</url>
# Updated line: <page>753</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=793</url>
# Updated line: <page>754</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=794</url>
# Updated line: <page>755</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=795</url>
# Updated line: <page>756</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=796</url>
# Updated line: <page>757</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=797</url>
# Updated line: <page>758</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=798</url>
# Updated line: <page>759</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=799</url>
# Updated line: <page>760</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=800</url>
# Updated line: <page>761</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=801</url>
# ...
# Updated line: <page>257</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=297</url>
# Updated line: <page>258</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=298</url>
# Updated line: <page>259</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=299</url>
# Updated line: <page>260</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=300</url>
# Updated line: <page>261</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=301</url>
# Updated line: <page>262</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=302</url>
# Updated line: <page>263</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=303</url>
# Updated line: <page>264</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=304</url>
# Updated line: <page>265</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=305</url>
# Finished processing file: ../output/sessions/4.September26-November07-1901/6-Tuesday, 8th October, 1501.txt
# Processing file: ../output/sessions/4.September26-November07-1901/7-Wednesday, 9th October, 1901.txt
# Updated line: <page>265</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=305</url>
# Updated line: <page>266</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=306</url>
# Updated line: <page>267</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=307</url>
# Updated line: <page>268</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=308</url>
# Updated line: <page>269</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=309</url>
# Updated line: <page>270</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=310</url>
# Updated line: <page>271</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=311</url>
# Updated line: <page>272</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=312</url>
# Updated line: <page>273</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=313</url>
# Updated line: <page>274</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=314</url>
# Updated line: <page>275</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=315</url>
# Updated line: <page>276</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=316</url>
# Updated line: <page>277</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=317</url>
# Updated line: <page>278</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=318</url>
# Updated line: <page>279</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=319</url>
# Updated line: <page>280</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=320</url>
# Updated line: <page>281</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=321</url>
# Updated line: <page>282</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=322</url>
# Updated line: <page>283</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=323</url>
# Updated line: <page>284</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=324</url>
# Updated line: <page>285</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=325</url>
# Updated line: <page>286</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=326</url>
# Updated line: <page>287</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=327</url>
# Updated line: <page>288</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=328</url>
# Updated line: <page>289</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=329</url>
# Updated line: <page>290</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=330</url>
# Updated line: <page>291</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=331</url>
# Updated line: <page>292</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=332</url>
# Updated line: <page>293</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=333</url>
# Updated line: <page>294</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=334</url>
# Updated line: <page>295</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=335</url>
# Updated line: <page>296</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=336</url>
# Updated line: <page>297</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=337</url>
# Updated line: <page>298</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=338</url>
# Updated line: <page>299</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=339</url>
# Updated line: <page>300</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=340</url>
# Updated line: <page>301</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=341</url>
# Updated line: <page>302</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=342</url>
# Updated line: <page>303</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=343</url>
# Updated line: <page>304</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=344</url>
# Updated line: <page>305</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=345</url>
# Updated line: <page>306</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=346</url>
# Updated line: <page>307</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=347</url>
# Finished processing file: ../output/sessions/4.September26-November07-1901/7-Wednesday, 9th October, 1901.txt
# Processing file: ../output/sessions/4.September26-November07-1901/8-Thursday, 10th October, 1901.txt
# Updated line: <page>307</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=347</url>
# Updated line: <page>308</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=348</url>
# Updated line: <page>309</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=349</url>
# Updated line: <page>310</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=350</url>
# Updated line: <page>311</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=351</url>
# Updated line: <page>312</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=352</url>
# Updated line: <page>313</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=353</url>
# Updated line: <page>314</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=354</url>
# Updated line: <page>315</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=355</url>
# Updated line: <page>316</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=356</url>
# Updated line: <page>317</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=357</url>
# Updated line: <page>318</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=358</url>
# Updated line: <page>319</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=359</url>
# Updated line: <page>320</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=360</url>
# Updated line: <page>321</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=361</url>
# Updated line: <page>322</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=362</url>
# Updated line: <page>323</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=363</url>
# Updated line: <page>324</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=364</url>
# Updated line: <page>325</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=365</url>
# Updated line: <page>326</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=366</url>
# Updated line: <page>327</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=367</url>
# Updated line: <page>328</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=368</url>
# Updated line: <page>329</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=369</url>
# Updated line: <page>330</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=370</url>
# Updated line: <page>331</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=371</url>
# Updated line: <page>332</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=372</url>
# Updated line: <page>333</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=373</url>
# Updated line: <page>334</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=374</url>
# Updated line: <page>335</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=375</url>
# Updated line: <page>336</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=376</url>
# Updated line: <page>337</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=377</url>
# Updated line: <page>338</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=378</url>
# Updated line: <page>339</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=379</url>
# Updated line: <page>340</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=380</url>
# Updated line: <page>341</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=381</url>
# Updated line: <page>342</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=382</url>
# Updated line: <page>343</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=383</url>
# Updated line: <page>344</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=384</url>
# Updated line: <page>345</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=385</url>
# Updated line: <page>346</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=386</url>
# Updated line: <page>347</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=387</url>
# Finished processing file: ../output/sessions/4.September26-November07-1901/8-Thursday, 10th October, 1901.txt
# Processing file: ../output/sessions/4.September26-November07-1901/9-Friday, 11th October, 1901.txt
# Updated line: <page>347</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=387</url>
# Updated line: <page>348</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=388</url>
# Updated line: <page>349</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=389</url>
# Updated line: <page>350</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=390</url>
# Updated line: <page>351</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=391</url>
# Updated line: <page>352</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=392</url>
# Updated line: <page>353</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=393</url>
# Updated line: <page>354</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=394</url>
# Updated line: <page>355</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=395</url>
# Updated line: <page>356</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=396</url>
# Updated line: <page>357</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=397</url>
# Updated line: <page>358</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=398</url>
# Updated line: <page>359</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=399</url>
# Updated line: <page>360</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=400</url>
# Updated line: <page>361</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=401</url>
# Updated line: <page>362</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=402</url>
# Updated line: <page>363</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=403</url>
# Updated line: <page>364</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=404</url>
# Updated line: <page>365</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=405</url>
# Updated line: <page>366</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=406</url>
# Updated line: <page>367</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=407</url>
# Updated line: <page>368</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=408</url>
# Updated line: <page>369</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=409</url>
# Updated line: <page>370</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=410</url>
# Updated line: <page>371</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=411</url>
# Updated line: <page>372</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=412</url>
# Updated line: <page>373</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=413</url>
# Updated line: <page>374</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=414</url>
# Updated line: <page>375</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=415</url>
# Updated line: <page>376</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=416</url>
# Updated line: <page>377</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=417</url>
# Updated line: <page>378</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=418</url>
# Updated line: <page>379</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=419</url>
# Updated line: <page>380</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=420</url>
# Updated line: <page>381</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=421</url>
# Updated line: <page>382</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=422</url>
# Updated line: <page>383</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=423</url>
# Updated line: <page>384</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=424</url>
# Updated line: <page>385</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=425</url>
# Updated line: <page>386</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=426</url>
# Updated line: <page>387</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=427</url>
# Updated line: <page>388</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=428</url>
# Updated line: <page>389</page> and <url>https://babel.hathitrust.org/cgi/pt?id=uc1.32106019788261&seq=429</url>
# Finished processing file: ../output/sessions/4.September26-November07-1901/9-Friday, 11th October, 1901.txt
